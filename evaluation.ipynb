# %% [markdown]
# # Evaluation

# %% [markdown]
# ### Final cross validation scores
# - 0.97 accuracy with a standard deviation of 0.01

# %% [markdown]
# High prediction accuracy with a relatively low deviation of 0.01

# %% [markdown]
# ### Dimension reduction

# %% [markdown]
# ![pca.png](attachment:pca.png)
